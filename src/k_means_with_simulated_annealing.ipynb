# %% [markdown]
# K means solution space is a function that has a global maximum among many local maximums.
# We will use simulated annealing to escape local maximum solutions.
#
#
# K Means algorithm:
#
#
#
# 1.   Initialize cluster centers randomly.
# 2.   Repeat until converged:
#
#   -Update cluster labels: Assign points to nearest cluster center(centroid).
#
#   -Update cluster centers(centroids): Set center to mean of each cluster.

# %% [markdown]
# Formula for finding nearest distance of point from centers(centroids):
#
#
# > Euclidean distance = d(p,q) = sqrt(sum((pi - qi)**2))

# %%
import numpy as np
import matplotlib.pyplot as plt


def euclidean_distance(x1, x2):
  return np.sqrt(np.sum((x1-x2)**2))


class KMeans:

  def __init__(self, K=5, max_iters=100, plot_steps=False):
    self.K = K
    self.max_iters = max_iters
    self.plot_steps = plot_steps

    # list of sample indices for each cluster 
    self.clusters = [[] for _ in range(self.K) ]

    # the centers (mean vector) for each cluster
    self.centroids = []
    
  def predict(self,X):
    self.X = X
    self.n_samples, self.n_features = X.shape

    # initialize the centroids
    random_sample_idxs = np.random.choice(self.n_samples, self.K, replace=False) # select K cluster centers from n samples without replacement (no repeated points).
    self.centroids = [self.X[idx] for idx in random_sample_idxs]

    # optimize clusters
    for _ in range(self.max_iters):
      # assign samples to closest centroids (create clusters)
      self.clusters = self._create_clusters(self.centroids)

      if self.plot_steps:
        self.plot()

      #calculate new centroids from the clusters
      centroids_old = self.centroids # saving so that we can see if results have converged
      self.centroids = self._get_centroids(self.clusters)

      if self._is_converged(centroids_old,  self.centroids):
        break

      if self.plot_steps:
        self.plot()

    # classify samples as the index of their clusters
    return self._get_cluster_labels(self.clusters), self._get_objective_value(self.clusters,self.centroids)

  def _get_cluster_labels(self, clusters):
    # each sample will get the label of the cluster it was assigned to 
    labels = np.empty(self.n_samples) 
    for cluster_idx, cluster in enumerate(clusters):
      for sample_idx in cluster:
        labels[sample_idx] = cluster_idx
    return labels
    
  def _get_objective_value(self,clusters,centroids):
    clusters_assignment_value = 0
    for centroid, cluster in zip(centroids,clusters):
      cluster_objective_value = 0
      for sample_point in cluster:
        if not cluster_objective_value:
          cluster_objective_value = euclidean_distance(sample_point,centroid)
        else:
          cluster_objective_value = cluster_objective_value + euclidean_distance(sample_point,centroid)
      if not clusters_assignment_value:
        clusters_assignment_value = cluster_objective_value
      else:
        clusters_assignment_value = cluster_objective_value + clusters_assignment_value
    return clusters_assignment_value

  # function to create clusters from centroids
  def _create_clusters(self, centroids):
    #assign samples to the closest centroids
    clusters = [[] for _ in range(self.K)]
    for idx, sample in enumerate(self.X):
      centroid_idx = self._closest_centroid(sample, centroids)
      clusters[centroid_idx].append(idx)
    return clusters 

  def _closest_centroid(self, sample, centroids):
    #distance of the current sample to each centroid
    distances = [euclidean_distance(sample, point) for point in centroids]
    closest_idx = np.argmin(distances)
    return closest_idx


  # function to return new calculated centroids
  def _get_centroids(self, clusters):
    # assign mean value of clusters to centroids
    centroids = np.zeros((self.K, self.n_features))
    
    for cluster_idx, cluster in enumerate(clusters):
      cluster_mean = np.mean(self.X[cluster], axis=0)
      centroids[cluster_idx] = cluster_mean 
    return centroids

  # function to check if kmeans is converged
  def _is_converged(self, centroids_old, centroids):
    # distances between old and new centroids, for all centroids
    distances = [euclidean_distance(centroids_old[i], centroids[i]) for i in range(self.K)]
    return sum(distances) == 0

  
  # function to plot centoids and clusters
  def plot(self):
    fig, ax = plt.subplots(figsize=(12, 8))
    for i, index in enumerate(self.clusters):
      point = self.X[index].T
      ax.scatter(*point)
    for point in self.centroids:
      ax.scatter(*point, marker="x", color="black", linewidth=2)
    plt.show()

# %%
# Testing 

# if __name__ == "__main__":
#   np.random.seed(42)
#   from sklearn.datasets import make_blobs
   
#   X, y = make_blobs(
#       centers=3, n_samples=500, n_features=2, shuffle=True, random_state=40
#   )
#   print(X.shape)

#   clusters = len(np.unique(y))
#   print(clusters)

#   k = KMeans(K=clusters, max_iters=150, plot_steps=False)
#   y_pred, objective_value = k.predict(X)
#   print(f"objective value: {round(objective_value)}")
#   #k.plot()

# plot function needs to be improved in order to present results of clustering datasets with more than 3 features.

if __name__ == "__main__":
  np.random.seed(42)
  from sklearn import datasets
  
  iris = datasets.load_iris()
  X = iris.data
  y = iris.target
  print(X.shape)

  clusters = len(np.unique(y))
  print(clusters)

  k = KMeans(K=clusters, max_iters=150, plot_steps=False)
  y_pred, objective_value = k.predict(X)
  print(f"objective value: {round(objective_value)}")

#  k.plot()
# Out:
# (150, 4)
# 3
# objective value: 21353

# %% [markdown]
# Simulated Annealing algorithm goes as follows for maximising given function h(x):
#
# 1.  Generate intial candidate solution.
# 2.  Get an initial temperature T > 0.
# 3.  for i in 1:N (N is number of iterations).
#
#   * Generate new candidate solution.
#   * Calculate probability p = exp(delta h / Ti), else accept x = x; delta h = h(x') - (x)
#   * Accept candidate solution with probability p; u ~ U(0,1), accept x = x', if u <= p.
#   * Update temperature (cooling), e.g. T = T*alpha, where 0 < alpha < 1
#
#
#
# Objective function we are trying to minimize: total sum of distances of each sample to its cluster centroid.
#
# If the sum is lower means each point is closer to its centroid, indicating a better solution.

# %%
import math
import numpy as np

def euclidean_distance(x1, x2):
  return np.sqrt(np.sum((x1-x2)**2))

class Simulated_Annealing:

  def __init__(self, temperature=1, alpha=0.95, K=5, max_iters=100, minimum_temperature=0.00001, plot_steps=False):
    self.K = K
    self.max_iters = max_iters
    self.plot_steps = plot_steps
    # list of sample indices for each cluster 
    self.clusters = [[] for _ in range(self.K) ]
    # the centers (mean vector) for each cluster
    self.centroids = []
    self.temperature = temperature
    self.minimum_temperature = minimum_temperature
    self.alpha = alpha
    self.accept_worse_state_count = 0 # to accept_worse_state_count step of algorithm
    self.worse_state_count = 0
    self.objective_value = 0 

  def predict(self,X):
    self.X = X
    self.n_samples, self.n_features = X.shape

    # checks if worse state gets rejected, so as to not calculate centroids, if there has been no change to clusters
    worse_state_rejected = False

    # initialize the centroids
    random_sample_idxs = np.random.choice(self.n_samples, self.K, replace=False) # select K cluster centers from n samples without replacement (no repeated points).
    self.centroids = [self.X[idx] for idx in random_sample_idxs]

    while self.temperature > self.minimum_temperature:

      print(f"temperature is: {self.temperature}")
      self.accept_worse_state_count = 0
      self.worse_state_count = 0
      # optimize clusters
      for _ in range(self.max_iters):
        # assign samples to closest centroids (create clusters)
        self.clusters = self._create_clusters(self.centroids)

        if self.plot_steps:
          self.plot()

        # generating a trial assignment by moving random point to random cluster.
        random_sample_point_idx = np.random.choice(self.n_samples, 1, replace=False)
        random_centroid_idx = np.random.choice(self.K, 1, replace=False)[0]

        # creating trial assignment
        clusters_trial_assignment = self.clusters.copy()
       
        for idx,cluster in enumerate(clusters_trial_assignment):
          if random_sample_point_idx in cluster:
            cluster.remove(random_sample_point_idx)
            #cluster.pop(cluster.index(random_sample_point_idx))        
        
        clusters_trial_assignment[random_centroid_idx].append(random_sample_point_idx[0])

        centroids_trial_assignment = self._get_centroids(clusters_trial_assignment)
        
        cluster_improvement_delta = self._get_objective_value(clusters_trial_assignment,centroids_trial_assignment) - self._get_objective_value(self.clusters,self.centroids)
        # if worse configuration than accept with probability
        if cluster_improvement_delta > 0:

          self.worse_state_count = self.worse_state_count + 1
          y = np.random.random(1)[0] 
          if (self._get_acceptance_probability(cluster_improvement_delta, self.temperature)) > y:
            self.clusters = clusters_trial_assignment
            self.centroids = centroids_trial_assignment
            self.objective_value = self._get_objective_value(self.clusters,self.centroids)
            self.accept_worse_state_count = self.accept_worse_state_count+1 # counting worse configuration acceptance ratio
          
          else:
            worse_state_rejected = True

        # if better state accept 
        elif cluster_improvement_delta < 0:
          self.clusters = clusters_trial_assignment
          self.centroids = centroids_trial_assignment
          self.objective_value = self._get_objective_value(self.clusters,self.centroids)
          worse_state_rejected = True

        if worse_state_rejected == False:
          # calculate new centroids from the clusters
          #centroids_old = self.centroids # saving so that we can see if results have converged
          self.centroids = self._get_centroids(self.clusters)
          worse_state_rejected = True
      
      print(f"percentage of worse states being accepted: {round(self.accept_worse_state_count/self.worse_state_count,2)*100}")
      self.temperature = self.temperature*self.alpha

      # if self._is_converged(centroids_old,  self.centroids):
      #   break

      if self.plot_steps:
        self.plot()

    # classify samples as the index of their clusters
    return self._get_cluster_labels(self.clusters), self._get_objective_value(self.clusters,self.centroids)

  def _get_objective_value(self,clusters,centroids):
    clusters_assignment_value = 0
    for centroid, cluster in zip(centroids,clusters):
      cluster_objective_value = 0
      for sample_point in cluster:
        if not cluster_objective_value:
          cluster_objective_value = euclidean_distance(sample_point,centroid)
        else:
          cluster_objective_value = cluster_objective_value + euclidean_distance(sample_point,centroid)
      if not clusters_assignment_value:
        clusters_assignment_value = cluster_objective_value
      else:
        clusters_assignment_value = cluster_objective_value + clusters_assignment_value
    return clusters_assignment_value

  def _get_acceptance_probability(self, delta, temperature):
    acceptance_probability =  math.exp(-(delta/temperature))
    return acceptance_probability

  def _get_cluster_labels(self, clusters):
    # each sample will get the label of the cluster it was assigned to 
    labels = np.empty(self.n_samples) 
    for cluster_idx, cluster in enumerate(clusters):
      for sample_idx in cluster:
        labels[sample_idx] = cluster_idx
    return labels
    
  # function to create clusters from centroids
  def _create_clusters(self, centroids):
    # assign samples to the closest centroids
    clusters = [[] for _ in range(self.K)]
    for idx, sample in enumerate(self.X):
      centroid_idx = self._closest_centroid(sample, centroids)
      clusters[centroid_idx].append(idx)
    return clusters 

  def _closest_centroid(self, sample, centroids):
    #distance of the current sample to each centroid
    distances = [euclidean_distance(sample, point) for point in centroids]
    closest_idx = np.argmin(distances)
    return closest_idx

  # function to return new calculated centroids
  def _get_centroids(self, clusters):
    # assign mean value of clusters to centroids
    centroids = np.zeros((self.K, self.n_features))
    for cluster_idx, cluster in enumerate(clusters):
      cluster_mean = np.mean(self.X[cluster], axis=0)
      centroids[cluster_idx] = cluster_mean 
    return centroids

  # function to check if kmeans is converged
  def _is_converged(self, centroids_old, centroids):
    # distances between old and new centroids, for all centroids
    distances = [euclidean_distance(centroids_old[i], centroids[i]) for i in range(self.K)]
    return sum(distances) == 0

  # function to plot centoids and clusters
  def plot(self):
    fig, ax = plt.subplots(figsize=(12, 8))
    for i, index in enumerate(self.clusters):
      point = self.X[index].T
      ax.scatter(*point)
    for point in self.centroids:
      ax.scatter(*point, marker="x", color="black", linewidth=2)
    plt.show()

# %%
# Testing 

# if __name__ == "__main__":
#   np.random.seed(42)
#   from sklearn.datasets import make_blobs
   
#   X, y = make_blobs(
#       centers=3, n_samples=100, n_features=2, shuffle=True, random_state=40
#   )
#   print(X.shape)

#   clusters = len(np.unique(y))
#   print(clusters)

#   k = Simulated_Annealing(temperature=100, alpha=0.95, K=clusters, max_iters=100, minimum_temperature=0.00001, plot_steps=False)
#   y_pred = k.predict(X)

  #k.plot()

if __name__ == "__main__":
  np.random.seed(42)
  from sklearn import datasets
  
  iris = datasets.load_iris()
  X = iris.data
  y = iris.target
  print(X.shape)

  clusters = len(np.unique(y))
  print(clusters)

  k = Simulated_Annealing(temperature=100, alpha=0.95, K=clusters, max_iters=100, minimum_temperature=0.00001, plot_steps=False)
  y_pred, objective_value = k.predict(X)
  print(f"objective_value:{round(objective_value)}")
# Out:
# (150, 4)
# 3
# temperature is: 100
# percentage of worse states being accepted: 100.0
# temperature is: 95.0
# percentage of worse states being accepted: 96.0
# temperature is: 90.25
# percentage of worse states being accepted: 98.0
# temperature is: 85.7375
# percentage of worse states being accepted: 93.0
# temperature is: 81.45062499999999
# percentage of worse states being accepted: 98.0
# temperature is: 77.37809374999999
# percentage of worse states being accepted: 98.0
# temperature is: 73.50918906249998
# percentage of worse states being accepted: 100.0
# temperature is: 69.83372960937498
# percentage of worse states being accepted: 95.0
# temperature is: 66.34204312890623
# percentage of worse states being accepted: 92.0
# temperature is: 63.02494097246091
# percentage of worse states being accepted: 100.0
# temperature is: 59.87369392383786
# percentage of worse states being accepted: 95.0
# temperature is: 56.880009227645964
# percentage of worse states being accepted: 95.0
# temperature is: 54.03600876626366
# percentage of worse states being accepted: 98.0
# temperature is: 51.33420832795048
# percentage of worse states being accepted: 100.0
# temperature is: 48.76749791155295
# percentage of worse states being accepted: 97.0
# temperature is: 46.3291230159753
# percentage of worse states being accepted: 94.0
# temperature is: 44.012666865176534
# percentage of worse states being accepted: 92.0
# temperature is: 41.812033521917705
# percentage of worse states being accepted: 94.0
# temperature is: 39.72143184582182
# percentage of worse states being accepted: 93.0
# temperature is: 37.73536025353073
# percentage of worse states being accepted: 98.0
# temperature is: 35.84859224085419
# percentage of worse states being accepted: 93.0
# temperature is: 34.05616262881148
# percentage of worse states being accepted: 98.0
# temperature is: 32.3533544973709
# percentage of worse states being accepted: 93.0
# temperature is: 30.735686772502355
# percentage of worse states being accepted: 100.0
# temperature is: 29.198902433877237
# percentage of worse states being accepted: 94.0
# temperature is: 27.738957312183373
# percentage of worse states being accepted: 93.0
# temperature is: 2.364956658822993
# percentage of worse states being accepted: 36.0
# temperature is: 2.2467088258818433
# percentage of worse states being accepted: 30.0
# temperature is: 2.134373384587751
# percentage of worse states being accepted: 26.0
# temperature is: 2.0276547153583633
# percentage of worse states being accepted: 36.0
# temperature is: 1.926271979590445
# percentage of worse states being accepted: 20.0
# temperature is: 1.8299583806109228
# percentage of worse states being accepted: 28.999999999999996
# temperature is: 1.7384604615803765
# percentage of worse states being accepted: 23.0
# temperature is: 1.6515374385013575
# percentage of worse states being accepted: 23.0
# temperature is: 1.5689605665762896
# percentage of worse states being accepted: 20.0
# temperature is: 1.490512538247475
# percentage of worse states being accepted: 22.0
# temperature is: 1.4159869113351014
# percentage of worse states being accepted: 22.0
# temperature is: 1.3451875657683463
# percentage of worse states being accepted: 14.000000000000002
# temperature is: 1.2779281874799289
# percentage of worse states being accepted: 21.0
# temperature is: 1.2140317781059324
# percentage of worse states being accepted: 10.0
# temperature is: 1.1533301892006358
# percentage of worse states being accepted: 23.0
# temperature is: 1.0956636797406039
# percentage of worse states being accepted: 10.0
# temperature is: 1.0408804957535736
# percentage of worse states being accepted: 20.0
# temperature is: 0.9888364709658948
# percentage of worse states being accepted: 17.0
# temperature is: 0.9393946474176
# percentage of worse states being accepted: 11.0
# temperature is: 0.89242491504672
# percentage of worse states being accepted: 9.0
# temperature is: 0.8478036692943839
# percentage of worse states being accepted: 10.0
# temperature is: 0.8054134858296647
# percentage of worse states being accepted: 5.0
# temperature is: 0.7651428115381814
# percentage of worse states being accepted: 10.0
# temperature is: 0.7268856709612723
# percentage of worse states being accepted: 9.0
# temperature is: 0.6905413874132087
# percentage of worse states being accepted: 5.0
# temperature is: 0.6560143180425483
# percentage of worse states being accepted: 5.0
# temperature is: 0.6232136021404209
# percentage of worse states being accepted: 5.0
# temperature is: 0.5920529220333998
# percentage of worse states being accepted: 4.0
# temperature is: 0.5624502759317298
# percentage of worse states being accepted: 9.0
# temperature is: 0.5343277621351433
# percentage of worse states being accepted: 4.0
# temperature is: 0.5076113740283862
# percentage of worse states being accepted: 6.0
# temperature is: 0.4822308053269668
# percentage of worse states being accepted: 5.0
# temperature is: 0.45811926506061845
# percentage of worse states being accepted: 7.000000000000001
# temperature is: 0.4352133018075875
# percentage of worse states being accepted: 4.0
# temperature is: 0.4134526367172081
# percentage of worse states being accepted: 4.0
# temperature is: 0.3927800048813477
# percentage of worse states being accepted: 2.0
# temperature is: 0.3731410046372803
# percentage of worse states being accepted: 5.0
# temperature is: 0.35448395440541625
# percentage of worse states being accepted: 5.0
# temperature is: 0.3367597566851454
# percentage of worse states being accepted: 5.0
# temperature is: 0.31992176885088813
# percentage of worse states being accepted: 2.0
# temperature is: 0.3039256804083437
# percentage of worse states being accepted: 2.0
# temperature is: 0.28872939638792655
# percentage of worse states being accepted: 2.0
# temperature is: 0.2742929265685302
# percentage of worse states being accepted: 2.0
# temperature is: 0.2605782802401037
# percentage of worse states being accepted: 4.0
# temperature is: 0.2475493662280985
# percentage of worse states being accepted: 5.0
# temperature is: 0.23517189791669357
# percentage of worse states being accepted: 3.0
# temperature is: 0.22341330302085888
# percentage of worse states being accepted: 2.0
# temperature is: 0.21224263786981593
# percentage of worse states being accepted: 1.0
# temperature is: 0.20163050597632512
# percentage of worse states being accepted: 5.0
# temperature is: 0.19154898067750886
# percentage of worse states being accepted: 3.0
# temperature is: 0.18197153164363342
# percentage of worse states being accepted: 1.0
# temperature is: 0.17287295506145173
# percentage of worse states being accepted: 4.0
# temperature is: 0.16422930730837915
# percentage of worse states being accepted: 3.0
# temperature is: 0.15601784194296017
# percentage of worse states being accepted: 6.0
# temperature is: 0.14821694984581216
# percentage of worse states being accepted: 1.0
# temperature is: 0.14080610235352153
# percentage of worse states being accepted: 2.0
# temperature is: 0.13376579723584545
# percentage of worse states being accepted: 6.0
# temperature is: 0.12707750737405316
# percentage of worse states being accepted: 4.0
# temperature is: 0.1207236320053505
# percentage of worse states being accepted: 3.0
# temperature is: 0.11468745040508296
# percentage of worse states being accepted: 3.0
# temperature is: 0.10895307788482882
# percentage of worse states being accepted: 1.0
# temperature is: 0.10350542399058738
# percentage of worse states being accepted: 4.0
# temperature is: 0.098330152791058
# percentage of worse states being accepted: 3.0
# temperature is: 0.09341364515150509
# percentage of worse states being accepted: 3.0
# temperature is: 0.08874296289392983
# percentage of worse states being accepted: 4.0
# temperature is: 0.08430581474923333
# percentage of worse states being accepted: 3.0
# temperature is: 0.08009052401177166
# percentage of worse states being accepted: 2.0
# temperature is: 0.07608599781118308
# percentage of worse states being accepted: 2.0
# temperature is: 0.07228169792062393
# percentage of worse states being accepted: 3.0
# temperature is: 0.06866761302459273
# percentage of worse states being accepted: 2.0
# temperature is: 0.0652342323733631
# percentage of worse states being accepted: 2.0
# temperature is: 0.061972520754694935
# percentage of worse states being accepted: 1.0
# temperature is: 0.05887389471696019
# percentage of worse states being accepted: 0.0
# temperature is: 0.05593019998111218
# percentage of worse states being accepted: 1.0
# temperature is: 0.053133689982056566
# percentage of worse states being accepted: 2.0
# temperature is: 0.05047700548295374
# percentage of worse states being accepted: 1.0
# temperature is: 0.047953155208806046
# percentage of worse states being accepted: 0.0
# temperature is: 0.04555549744836574
# percentage of worse states being accepted: 0.0
# temperature is: 0.043277722575947454
# percentage of worse states being accepted: 0.0
# temperature is: 0.04111383644715008
# percentage of worse states being accepted: 1.0
# temperature is: 0.039058144624792575
# percentage of worse states being accepted: 2.0
# temperature is: 0.037105237393552946
# percentage of worse states being accepted: 1.0
# temperature is: 0.0352499755238753
# percentage of worse states being accepted: 1.0
# temperature is: 0.03348747674768154
# percentage of worse states being accepted: 2.0
# temperature is: 0.03181310291029746
# percentage of worse states being accepted: 0.0
# temperature is: 0.030222447764782584
# percentage of worse states being accepted: 0.0
# temperature is: 0.028711325376543452
# percentage of worse states being accepted: 0.0
# temperature is: 0.027275759107716277
# percentage of worse states being accepted: 2.0
# temperature is: 0.025911971152330463
# percentage of worse states being accepted: 1.0
# temperature is: 0.02461637259471394
# percentage of worse states being accepted: 0.0
# temperature is: 0.02338555396497824
# percentage of worse states being accepted: 0.0
# temperature is: 0.022216276266729326
# percentage of worse states being accepted: 1.0
# temperature is: 0.02110546245339286
# percentage of worse states being accepted: 2.0
# temperature is: 0.020050189330723216
# percentage of worse states being accepted: 0.0
# temperature is: 0.019047679864187053
# percentage of worse states being accepted: 0.0
# temperature is: 0.0180952958709777
# percentage of worse states being accepted: 1.0
# temperature is: 0.017190531077428815
# percentage of worse states being accepted: 0.0
# temperature is: 0.016331004523557374
# percentage of worse states being accepted: 0.0
# temperature is: 0.015514454297379505
# percentage of worse states being accepted: 1.0
# temperature is: 0.014738731582510529
# percentage of worse states being accepted: 1.0
# temperature is: 0.014001795003385002
# percentage of worse states being accepted: 0.0
# temperature is: 0.013301705253215751
# percentage of worse states being accepted: 0.0
# temperature is: 0.012636619990554963
# percentage of worse states being accepted: 1.0
# temperature is: 0.012004788991027214
# percentage of worse states being accepted: 0.0
# temperature is: 0.011404549541475852
# percentage of worse states being accepted: 2.0
# temperature is: 0.010834322064402059
# percentage of worse states being accepted: 0.0
# temperature is: 0.010292605961181955
# percentage of worse states being accepted: 1.0
# temperature is: 0.009777975663122856
# percentage of worse states being accepted: 0.0
# temperature is: 0.009289076879966713
# percentage of worse states being accepted: 0.0
# temperature is: 0.008824623035968376
# percentage of worse states being accepted: 0.0
# temperature is: 0.008383391884169956
# percentage of worse states being accepted: 0.0
# temperature is: 0.007964222289961458
# percentage of worse states being accepted: 0.0
# temperature is: 0.007566011175463384
# percentage of worse states being accepted: 0.0
# temperature is: 0.0071877106166902145
# percentage of worse states being accepted: 0.0
# temperature is: 0.006828325085855703
# percentage of worse states being accepted: 0.0
# temperature is: 0.006486908831562918
# percentage of worse states being accepted: 0.0
# temperature is: 0.006162563389984772
# percentage of worse states being accepted: 0.0
# temperature is: 0.005854435220485533
# percentage of worse states being accepted: 0.0
# temperature is: 0.005561713459461257
# percentage of worse states being accepted: 0.0
# temperature is: 0.005283627786488194
# percentage of worse states being accepted: 0.0
# temperature is: 0.005019446397163784
# percentage of worse states being accepted: 0.0
# temperature is: 0.004768474077305594
# percentage of worse states being accepted: 0.0
# temperature is: 0.004530050373440314
# percentage of worse states being accepted: 0.0
# temperature is: 0.004303547854768298
# percentage of worse states being accepted: 0.0
# temperature is: 0.004088370462029883
# percentage of worse states being accepted: 0.0
# temperature is: 0.0038839519389283887
# percentage of worse states being accepted: 0.0
# temperature is: 0.003689754341981969
# percentage of worse states being accepted: 0.0
# temperature is: 0.0035052666248828706
# percentage of worse states being accepted: 0.0
# temperature is: 0.003330003293638727
# percentage of worse states being accepted: 0.0
# temperature is: 0.0031635031289567904
# percentage of worse states being accepted: 0.0
# temperature is: 0.003005327972508951
# percentage of worse states being accepted: 0.0
# temperature is: 0.002855061573883503
# percentage of worse states being accepted: 0.0
# temperature is: 0.002712308495189328
# percentage of worse states being accepted: 0.0
# temperature is: 0.0025766930704298613
# percentage of worse states being accepted: 0.0
# temperature is: 0.0024478584169083683
# percentage of worse states being accepted: 0.0
# temperature is: 0.00232546549606295
# percentage of worse states being accepted: 0.0
# temperature is: 0.002209192221259802
# percentage of worse states being accepted: 0.0
# temperature is: 0.0020987326101968118
# percentage of worse states being accepted: 0.0
# percentage of worse states being accepted: 0.0
# temperature is: 0.00018835040536990848
# percentage of worse states being accepted: 0.0
# temperature is: 0.00017893288510141306
# percentage of worse states being accepted: 0.0
# temperature is: 0.0001699862408463424
# percentage of worse states being accepted: 0.0
# temperature is: 0.00016148692880402527
# percentage of worse states being accepted: 0.0
# temperature is: 0.000153412582363824
# percentage of worse states being accepted: 0.0
# temperature is: 0.0001457419532456328
# percentage of worse states being accepted: 0.0
# temperature is: 0.00013845485558335117
# percentage of worse states being accepted: 0.0
# temperature is: 0.0001315321128041836
# percentage of worse states being accepted: 0.0
# temperature is: 0.00012495550716397442
# percentage of worse states being accepted: 0.0
# temperature is: 0.00011870773180577569
# percentage of worse states being accepted: 0.0
# temperature is: 0.0001127723452154869
# percentage of worse states being accepted: 0.0
# temperature is: 0.00010713372795471255
# percentage of worse states being accepted: 0.0
# temperature is: 0.00010177704155697692
# percentage of worse states being accepted: 0.0
# temperature is: 9.668818947912807e-05
# percentage of worse states being accepted: 0.0
# temperature is: 9.185378000517166e-05
# percentage of worse states being accepted: 0.0
# temperature is: 8.726109100491307e-05
# percentage of worse states being accepted: 0.0
# temperature is: 8.289803645466741e-05
# percentage of worse states being accepted: 0.0
# temperature is: 7.875313463193404e-05
# percentage of worse states being accepted: 0.0
# temperature is: 7.481547790033734e-05
# percentage of worse states being accepted: 0.0
# temperature is: 7.107470400532047e-05
# percentage of worse states being accepted: 0.0
# temperature is: 6.752096880505445e-05
# percentage of worse states being accepted: 0.0
# temperature is: 6.414492036480173e-05
# percentage of worse states being accepted: 0.0
# temperature is: 6.0937674346561646e-05
# percentage of worse states being accepted: 0.0
# temperature is: 5.789079062923356e-05
# percentage of worse states being accepted: 0.0
# temperature is: 5.499625109777188e-05
# percentage of worse states being accepted: 0.0
# temperature is: 5.224643854288328e-05
# percentage of worse states being accepted: 0.0
# temperature is: 4.963411661573912e-05
# percentage of worse states being accepted: 0.0
# temperature is: 4.715241078495216e-05
# percentage of worse states being accepted: 0.0
# temperature is: 4.479479024570455e-05
# percentage of worse states being accepted: 0.0
# temperature is: 4.2555050733419325e-05
# percentage of worse states being accepted: 0.0
# temperature is: 4.042729819674836e-05
# percentage of worse states being accepted: 0.0
# temperature is: 3.840593328691094e-05
# percentage of worse states being accepted: 0.0
# temperature is: 3.648563662256539e-05
# percentage of worse states being accepted: 0.0
# temperature is: 3.4661354791437114e-05
# percentage of worse states being accepted: 0.0
# temperature is: 3.2928287051865256e-05
# percentage of worse states being accepted: 0.0
# temperature is: 3.128187269927199e-05
# percentage of worse states being accepted: 0.0
# temperature is: 2.9717779064308393e-05
# percentage of worse states being accepted: 0.0
# temperature is: 2.823189011109297e-05
# percentage of worse states being accepted: 0.0
# temperature is: 2.6820295605538322e-05
# percentage of worse states being accepted: 0.0
# temperature is: 2.5479280825261406e-05
# percentage of worse states being accepted: 0.0
# temperature is: 2.4205316783998335e-05
# percentage of worse states being accepted: 0.0
# temperature is: 2.2995050944798418e-05
# percentage of worse states being accepted: 0.0
# temperature is: 2.1845298397558495e-05
# percentage of worse states being accepted: 0.0
# temperature is: 2.075303347768057e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.9715381803796542e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.8729612713606715e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.779313207792638e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.690347547403006e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.6058301700328556e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.5255386615312127e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.449261728454652e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.3767986420319193e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.3079587099303233e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.242560774433807e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.1804327357121166e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.1214110989265108e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.0653405439801852e-05
# percentage of worse states being accepted: 0.0
# temperature is: 1.0120735167811759e-05
# percentage of worse states being accepted: 0.0
# objective_value:21349
